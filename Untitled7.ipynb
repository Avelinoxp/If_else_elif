# %% [markdown]
# <a href="https://colab.research.google.com/github/Avelinoxp/If_else_elif/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IF/ ELSE

# %%
#if é a declaração mais simples de tomada de decisão.

#Ele é usado para decidir se uma determinada instrução ou bloco de instruções será
#executado ou não, ou seja, se uma determinada condição for verdadeira, um bloco de
#instruções será executado, caso contrário, não.
#if condição :
#declarações a serem executadas se
#condição é verdadeira

# %%
#Atividade1
idade = int(input('Digite sua idade:'))
if idade >= 18:
  print('Voce é maior de idade')
else:
  print('Voce é menor de idade')
# Out:
# Digite sua idade:17
# Voce é menor de idade

# %%
#1-Você foi contratado para desenvolver um sistema simples de pagamento online. O sistema deve
#identificar o método de pagamento escolhido pelo usuário e exibir a mensagem correspondente:
#Se o usuário escolher "cartao", o programa deve exibir: "Processando pagamento no cartão...".
#Se o usuário escolher "boleto", o programa deve exibir: "Gerando boleto bancário...".
#Para qualquer outro método, o programa deve exibir: "Método de pagamento não reconhecido.".

usuario = input('Digite a forma de pagamento (cartão/boleto):').lower()
if usuario == 'Cartão':
 print('Processando pagamento no cartão')
elif usuario == "boleto":
 print('Gerando boleto bancário...')
else:
  print('Método de pagamento não identificado')
# Out:
# Digite a forma de pagamento (cartão/boleto):boleto
# Gerando boleto bancário...

# %%
 #2-Crie um programa que solicita a idade de uma pessoa e classifica-a em uma das seguintes
#categorias:
idade = int(input('Digite sua idade'))
if idade <= 12:
  print('Criança')
elif idade >= 13 and idade <= 17:
  print('Adolecente')
elif idade >= 18 and idade <= 59:
  print('Adulto')
elif idade >= 60:
  print('Idoso')
# Out:
# Digite sua idade22
# Adulto

# %%
#3-Uma loja oferece descontos progressivos de acordo com o valor da compra. Escreva um
#programa em Python que solicita o valor total da compra e aplica o desconto conforme a
#tabela abaixo:
valor = float(input('Digite o valor total da compra' ))
if valor >= 60:
  print('Aplique o desconto')
elif valor <=59:
  print('Desconto indisponível')
# Out:
# Digite o valor total da compra50
# Desconto indisponível

# %%
#3-Uma loja online permite que seus clientes escolham entre dois tipos de entrega:
#"padrão": Custa R$10,00.
#"expresso": Custa R$20,00.
#Qualquer outra opção deve exibir: "Opção de entrega inválida.".
entrega = (input('Selecione sua escolha de frete: '))
if entrega == 'padrão':
  print(' Entrega padrão: R$10,00')
elif entrega == 'expresso':
  print('Entrega expresso: R$20,00')
elif entrega == 'Premium':
  print('Entrega Premium: R$30,00')
else:
  print('Opção de entrega inválida.')
# Out:
# Selecione sua escolha de frete: Premium
# Entrega Premium: R$30,00

# %%
#Objetivo: usar if e else
#Crie um programa que:
#Peça um número
#Verifique se ele é:
#Positivo
#Negativo
numero = float(input('Digite um numero'))
if numero > 0:
  print('Positivo')
elif numero == 0:
  print('Neutro')
elif numero < 0:
  print('Negativo')
# Out:
# Digite um numero-1
# Negativo

# %%
#Atividade 2 — Par ou Ímpar
numero = int(input('Adicione um número:'))
if numero % 2 == 0:
  print('O número é par')
else:
  print(' O número é Ímpar')
# Out:
# Adicione um número:24
# O número é par

# %%
#Atividade 3 — Sistema de notas
notas = float(input('Classifique a nota'))
if notas >= 7:
  print('Aprovado')
elif notas >= 5:
  print('Em recuperação')
else:
  print('Reprovado')
# Out:
# Classifique a nota9
# Aprovado

# %%
#Atividade 4 — Simulação de login simples
usuario = input('Digite seu login:')
senha = int(input('Digite sua senha:'))
if usuario == 'admin' and senha == 1234:
  print('Usuario correto')
else:
  print('Usuario ou senha incorretos')
# Out:
# Digite seu login:admin
# Digite sua senha:1233
# Usuario ou senha incorretos
